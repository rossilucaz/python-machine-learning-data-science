# %% [markdown]
# # Manipulando Variáveis e Constantes

# %% [markdown]
# - Variáveis são utilizadas para armazenar os dados
#
# - Qualquer dado que possa ser alterado no decorrer do tempo é uma variável.
#
# - Se o dado não tem possibilidade de variar no decorrer do tempo é uma constante.
#
# Ex: Calacular a área de um triângulo. A formula Base * Altura / 2
# Base e Altura são os dados que irão variar ao decorrer do "tempo de execução", já o número 2 da fórmula é uma constante pois sempre será o mesmo valor.

# %% [markdown]
# Tipos de Variáveis
#
# - Inteiros: Valores positivos ou negativos, que não tem parte fracionária.
#
# - Float(real): Valores positivos ou negativos, que podem ter uma parte fracionária (tambem podem ser inteiros).
#
# - Caracteres(char ou string): Qualquer elemento presente no teclado.
#
# - Lógico(boleano): Verdadeiro(1) ou falso(0)

# %% [markdown]
# ## Variáveis Inteiras

# %%
number = -9
number2 = 18
number3 = 36

# %% [markdown]
# ## Variáveis Float

# %%
pi = 3.14
number_euler = 2.71
number - 4.35
# Out:
# -13.35

# %% [markdown]
# ## String e Chars

# %%
letter = 'l'
word = 'language programming'
word2 = 'Python'

# %% [markdown]
# ## Input

# %%
age = int(input('Enter with your age: '))
print(f'Your age is... {age}')
# Out:
# Your age is... 5

# %%
ph = float(input('What was the soil PH during the last measurement?'))
print('The measured PH was:',ph)
# Out:
# The measured pH was: 5.0

# %%
name = str(input('What is your name?'))
print('Your name is', name)
# Out:
# Your name is lucas

# %% [markdown]
# # String Manipulate

# %%
str1 = 'whatever'
str1
# Out:
# 'whatever'

# %%
upper_str = str1.upper()
print(upper_str)
# Out:
# WHATEVER

# %%
lower_str = upper_str.lower()
lower_str
# Out:
# 'whatever'

# %%
capitalize_str = str1.capitalize()
print(capitalize_str)
# Out:
# Whatever

# %%
mean_word = str1[0:3]
print(mean_word)
# Out:
# wha

# %%
last_letter = str1[3:]
last_letter
# Out:
# 'tever'

# %%
str2 = str1.replace('wha', 'AAAAAAA')
str2
# Out:
# 'AAAAAAAtever'

# %%
str3 = str1.replace('r', 'O')
str3
# Out:
# 'whateveO'

# %%
str3.find('o')
# Out:
# -1

# %%
str3.find('O')
# Out:
# 7

# %%
str3.find('e')
# Out:
# 4

# %%
str4 = 'Hellooooooo'
len_str = len(str4)
len_str
# Out:
# 11

# %%
number1 = 9
number2 = 10
print(f'{number1} / {number2} = {number1 / number2}')
# Out:
# 9 / 10 = 0.9

# %% [markdown]
# # Math Operations

# %%
value = 5
value2 = 3
print(value, value2)
# Out:
# 5 3

# %%
addition = value + value2
addition
# Out:
# 8

# %%
subtraction = value - value2 
subtraction
# Out:
# 2

# %%
multiplication = value * value2
multiplication
# Out:
# 15

# %%
divison = value / value2
divison
# Out:
# 1.6666666666666667

# %%
remainder_division = value % value2
remainder_division
# Out:
# 2

# %%
exponentiation = value**3
exponentiation
# Out:
# 125

# %%
from math import sqrt

sqrt(81)
# Out:
# 9.0

# %% [markdown]
# ## Rounding

# %%
case_disease = 134
numbers_inhabitants = 34432

cases_per_inhabitant = case_disease / numbers_inhabitants
cases_per_inhabitant
# Out:
# 0.003891728624535316

# %%
round(cases_per_inhabitant, 6)
# Out:
# 0.003892

# %%
round(cases_per_inhabitant, 3)
# Out:
# 0.004

# %% [markdown]
# # Logical and Relational Operators

# %% [markdown]
# ## Logical Operators

# %%
x = True
y = False

# %%
x and y
x & y
# Out:
# False

# %%
print(f"'X' and 'Y' is equals: {x and y}")
# Out:
# 'X' and 'Y' is equals: False

# %%
x or y
x | y
# Out:
# True

# %%
print(f"'X' or 'Y' is equals: {x or y}")
# Out:
# 'X' or 'Y' is equals: True

# %%
not x
# Out:
# False

# %%
not y
# Out:
# True

# %% [markdown]
# ## Relational Operators

# %%
10 > 5
# Out:
# True

# %%
9 < 10
# Out:
# True

# %%
9 >= 10
# Out:
# False

# %%
9 <= 10
# Out:
# True

# %%
9 == 10
# Out:
# False

# %%
9 != 10
# Out:
# True

# %% [markdown]
# # Conditional Operator

# %%
9 < 10
# Out:
# True

# %%
if 9 > 6:
    print('9 is greater than 6')
# print('opaaaa')
# Out:
# 9 is greater than 6

# %%
if 5 > 6:
    print(' 5 is greater')
else:
    print('isnt greater')
# Out:
# isnt greater

# %%
n = 9
if n == 4:
    print('n isnt equal 4') 
else:
    if n == 9:
        print('n is equal 9')
    else: 
        print('n isnt equal to 4 and 9')
# Out:
# n is equal 9

# %%
x = 2 
y = 4

if (x > 1) and (y % 2  == 0):
    print('X greater than 1 and y is even')
else:
    print('something is wrong ')
# Out:
# X greater than 1 and y is even

# %%
x = 1 
y = 3

if (x > 1) or (y % 2  == 0):
    print('X greater than 1 and y is even')
else:
    print('something is wrong ')
# Out:
# something is wrong

# %% [markdown]
# # Loop For

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for  i in range(5, 0 , -1):
    print(i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
sum = 0
for i in range(1,6):
    sum += i
    print(sum)
print(sum)
# Out:
# 1
# 3
# 6
# 10
# 15
# 15

# %%
word = 'ice cream'
for i in word:
    print(i)
    if i == 'r':
        print('Found the word r ')
# Out:
# i
# c
# e
#
# c
# r
# Found the word r
# e
# a
# m

# %%
for i in range(5):
    print(i)
    print('-')
    for ii in range(3):
        print(ii)
    print()
# Out:
# 0
# -
# 0
# 1
# 2
#
# 1
# -
# 0
# 1
# 2
#
# 2
# -
# 0
# 1
# 2
#
# 3
# -
# 0
# 1
# 2
#
# 4
# -
# 0
# 1
# 2

# %% [markdown]
# # Loop While

# %%
number = 1
while number < 6:
    print(number)
    number += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
number = 5 
while number > 0:
    print(number)
    number -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
sum = 0
number = 1
 
while number < 5:
    sum += number
    number +=1
print(sum)
# Out:
# 10

# %%
number = -1
while number < 1 or number > 10:
    number = int(input('Enter a number from 1 to 10'))

# %% [markdown]
# # Collections

# %% [markdown]
# ## Tuple

# %%
tuple = ('Homo Sapiens', 'Canis Familiaris', 'Felis Catus')
tuple[-1]
# Out:
# 'Felis Catus'

# %%
tuple.index('Felis Catus')
# Out:
# 2

# %%
for i in tuple:
    print(i)
# Out:
# Homo Sapiens
# Canis Familiaris
# Felis Catus

# %% [markdown]
# ## List

# %%
list1 = ['Homo Sapiens', 'Canis Familiaris', 'Felis Catus']
list2 = ['Xenopus Leavis' , 'Ailuropoda Melanoleuca']

# %%
list3 = list1 + list2

# %%
result = " ".join(list1 + list2)
result
# Out:
# 'Homo Sapiens Canis Familiaris Felis Catus Xenopus Leavis Ailuropoda Melanoleuca'

# %%
list2_2 = list2 * 2
list2_2
# Out:
# ['Xenopus Leavis',
#  'Ailuropoda Melanoleuca',
#  'Xenopus Leavis',
#  'Ailuropoda Melanoleuca']

# %%
list1[0]
# Out:
# 'Homo Sapiens'

# %%
list1[0:2]
# Out:
# ['Homo Sapiens', 'Canis Familiaris']

# %%
list1.append('Monkey')
list1
# Out:
# ['Homo Sapiens', 'Canis Familiaris', 'Felis Catus', 'Monkey']

# %%
list1.remove('Canis Familiaris')
list1

# %%
del(list1)
list1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\lucas\Documents\WorkSpace\Pessoal\machine-leaning\basic-python.ipynb Cell 89 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/WorkSpace/Pessoal/machine-leaning/basic-python.ipynb#Y154sZmlsZQ%3D%3D?line=0'>1</a> del(list1)
#       <a href='vscode-notebook-cell:/c%3A/Users/lucas/Documents/WorkSpace/Pessoal/machine-leaning/basic-python.ipynb#Y154sZmlsZQ%3D%3D?line=1'>2</a> list1
#
# NameError: name 'list1' is not defined

# %%
for i in list2_2:
    print(i)
# Out:
# Xenopus Leavis
# Ailuropoda Melanoleuca
# Xenopus Leavis
# Ailuropoda Melanoleuca

# %% [markdown]
# ## Dictionary

# %%
collect = {'Aedes aegypt': 32, 'Aedes albopictus': 22, 'Anpheles darlingi': 14}

# %%
collect['Aedes aegypt']
# Out:
# 32

# %%
collect['Rhodnius montenegrensis'] = 11

# %%
collect
# Out:
# {'Aedes aegypt': 32,
#  'Aedes albopictus': 22,
#  'Anpheles darlingi': 14,
#  'Rhodnius montenegrensis': 11}

# %%
del(collect)['Aedes albopictus']

# %%
collect.items()
# Out:
# dict_items([('Aedes aegypt', 32), ('Anpheles darlingi', 14), ('Rhodnius montenegrensis', 11)])

# %%
collect.keys()
# Out:
# dict_keys(['Aedes aegypt', 'Anpheles darlingi', 'Rhodnius montenegrensis'])

# %%
collect.values()
# Out:
# dict_values([32, 14, 11])

# %%
collect2 = {'Anopheles gambiar': 13, 'Anopheles deaneorum': 14}

# %%
collect.update(collect2)

# %%
collect
# Out:
# {'Aedes aegypt': 32,
#  'Anpheles darlingi': 14,
#  'Rhodnius montenegrensis': 11,
#  'Anopheles gambiar': 13,
#  'Anopheles deaneorum': 14}

# %%
collect.items()
# Out:
# dict_items([('Aedes aegypt', 32), ('Anpheles darlingi', 14), ('Rhodnius montenegrensis', 11), ('Anopheles gambiar', 13), ('Anopheles deaneorum', 14)])

# %%
for i, ii in collect.items():
    print(f'Species {i}, number of species collected {ii}')
# Out:
# Species Aedes aegypt, number of species collected 32
# Species Anpheles darlingi, number of species collected 14
# Species Rhodnius montenegrensis, number of species collected 11
# Species Anopheles gambiar, number of species collected 13
# Species Anopheles deaneorum, number of species collected 14

# %% [markdown]
# ## Set

# %%
biomolecules = ('protein', 'nucleic acid', 'carbohydrate', 'lipid', 'nucleic acid', 'carbohydrate', 'carbohydrate','carbohydrate' )

# %%
set(biomolecules)
# Out:
# {'carbohydrate', 'lipid', 'nucleic acid', 'protein'}

# %%
c1 = {1,2,3,4,5}
c2 = {3,4,5,6,7,}
c3 = c1.intersection(c2)

# %%
c3
# Out:
# {3, 4, 5}

# %%
c1.difference(c2)
# Out:
# {1, 2}

# %%
c2.difference(c1)
# Out:
# {6, 7}

# %% [markdown]
# # Matrix

# %%
import numpy as np

# %%
matrix = np.array([[2, 3, 1,],
                   [4,5,7]])

# %%
matrix
# Out:
# array([[2, 3, 1],
#        [4, 5, 7]])

# %%
matrix.shape
# Out:
# (2, 3)

# %%
matrix[0]
# Out:
# array([2, 3, 1])

# %%
matrix[1]
# Out:
# array([4, 5, 7])

# %%
matrix[0][2]
# Out:
# 1

# %%
matrix[1][2]
# Out:
# 7

# %%
for i in range(matrix.shape[0]):
    print(matrix[i])
    for ii in range(matrix.shape[1]):
        print(matrix[i][ii])
# Out:
# [2 3 1]
# 2
# 3
# 1
# [4 5 7]
# 4
# 5
# 7

# %% [markdown]
# # Fuction
# - Trechos de programa que recebe um determinado nomer e podem ser chamados várias vezes durante a execução
# - Principais vantagens: Reutilização de código, modularidade e facilidade de manutenção do sistema.

# %% [markdown]
# ## Função sem parâmetro e sem retorno

# %%
def mensage():
    print('Function Text')

# %%
mensage()
# Out:
# Function Text

# %% [markdown]
# ## Função com passagem de parâmetro

# %%
def mensage(text):
    print(text)

# %%
mensage('text 1')
mensage('text 2')
mensage('text 3')
# Out:
# text 1
# text 2
# text 3

# %%
def sum(a, b):
    print(a + b)

# %%
sum(3,3)
# Out:
# 6

# %% [markdown]
# ## Função com passagem de parâmetros e retorno

# %%
def sum(a, b):
    return a + b

# %%
result = sum(9, 8)
result
# Out:
# 17

# %%
def calcular_energia_potencial_gravitacional(m, h, g = 10):
    '''
    Calcula a energia pontencial gravitacional
    
    Argumentos:
    m: massa, entrada como uma variável float
    h: altura, entrada como uma variável float
    
    Argumentos opcional:
    g: aceleração gravitacional, com valor default de 10
    '''
    energy = g * m * h
    return energy

# %%
calcular_energia_potencial_gravitacional(30, 12)
# Out:
# 3600

# %%
calcular_energia_potencial_gravitacional(30, 12, 9.8)
# Out:
# 3528.0

# %%
help(calcular_energia_potencial_gravitacional)
# Out:
# Help on function calcular_energia_potencial_gravitacional in module __main__:
#
# calcular_energia_potencial_gravitacional(m, h, g=10)
#     Calcula a energia pontencial gravitacional
#
#     Argumentos:
#     m: massa, entrada como uma variável float
#     h: altura, entrada como uma variável float
#
#     Argumentos opcional:
#     g: aceleração gravitacional, com valor default de 10
